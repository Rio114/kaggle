# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import pickle

from keras import models

# %%
FOLDER = "../../data_kaggle/freesound/"
PREPROCESS = FOLDER + "preprocessed_dataset/"
OUTPUT = FOLDER + "out/"

num_freq = 128
len_div = 256

model = models.load_model(OUTPUT+'20190517_CNN_model.h5', compile=False)

# %%
INPUT_FOLDER = FOLDER + "input/"
SAMPLE_SUBMISSION_PATH = INPUT_FOLDER + "sample_submission.csv"
TEST = INPUT_FOLDER + "test/"
sample = pd.read_csv(SAMPLE_SUBMISSION_PATH)

# %%
with open(PREPROCESS+'test_arr_0.pickle', 'rb') as f:
    X_test = pickle.load(f)
    file_name = pickle.load(f)

y_pred = model.predict(X_test.reshape([-1, num_freq, len_div,1]))

# %%
df_pred = pd.DataFrame(y_pred, columns=sample.columns[1:])
df_pred.head()
# Out:
#    Accelerating_and_revving_and_vroom  Accordion  Acoustic_guitar  Applause  \
# 0                            0.001884   0.003096         0.005911  0.002846
# 1                            0.037410   0.002351         0.002419  0.002114
# 2                            0.007451   0.000571         0.012605  0.000485
# 3                            0.029096   0.001137         0.001985  0.006459
# 4                            0.002704   0.000891         0.000770  0.003065
#
#        Bark  Bass_drum  Bass_guitar  Bathtub_(filling_or_washing)  \
# 0  0.003938   0.029490     0.016985                      0.002642
# 1  0.000322   0.028842     0.116336                      0.000366
# 2  0.000444   0.128871     0.050547                      0.007274
# 3  0.002482   0.007694     0.006102                      0.010786
# 4  0.003242   0.001629     0.001875                      0.018459
#
#    Bicycle_bell  Burping_and_eructation  ...  Toilet_flush  \
# 0      0.039185                0.010393  ...      0.013232
# 1      0.001327                0.001693  ...      0.007420
# 2      0.001180                0.005982  ...      0.006785
# 3      0.001156                0.007005  ...      0.012058
# 4      0.001690                0.006739  ...      0.003665
#
#    Traffic_noise_and_roadway_noise  Trickle_and_dribble  Walk_and_footsteps  \
# 0                         0.012250             0.005849            0.006064
# 1                         0.000719             0.000377            0.001667
# 2                         0.000337             0.000824            0.000967
# 3                         0.001664             0.006351            0.011930
# 4                         0.000621             0.005969            0.028185
#
#    Water_tap_and_faucet  Waves_and_surf  Whispering   Writing      Yell  \
# 0              0.010967        0.002437    0.016901  0.010545  0.008778
# 1              0.013575        0.000809    0.001478  0.020437  0.001389
# 2              0.038791        0.000076    0.003901  0.019255  0.000827
# 3              0.016373        0.000901    0.009064  0.024532  0.002560
# 4              0.010478        0.001047    0.025795  0.039417  0.000639
#
#    Zipper_(clothing)
# 0           0.009321
# 1           0.003472
# 2           0.012199
# 3           0.251498
# 4           0.085939
#
# [5 rows x 80 columns]

# %%
se_fname = pd.Series(file_name, name=sample.columns[0])
se_fname.head(20)
# Out:
# 0     000ccb97.wav
# 1     0012633b.wav
# 2     0012633b.wav
# 3     0012633b.wav
# 4     001ed5f1.wav
# 5     00294be0.wav
# 6     00294be0.wav
# 7     00294be0.wav
# 8     00294be0.wav
# 9     003fde7a.wav
# 10    003fde7a.wav
# 11    003fde7a.wav
# 12    003fde7a.wav
# 13    0040ccc9.wav
# 14    0046b732.wav
# 15    004f3bbc.wav
# 16    004f3bbc.wav
# 17    00526050.wav
# 18    00559da4.wav
# 19    00559da4.wav
# Name: fname, dtype: object

# %%
df_pred.shape
# Out:
# (2481, 80)

# %%
df_temp = pd.concat([se_fname, df_pred], axis=1)
df_temp.head()
# Out:
#           fname  Accelerating_and_revving_and_vroom  Accordion  \
# 0  000ccb97.wav                            0.001884   0.003096
# 1  0012633b.wav                            0.037410   0.002351
# 2  0012633b.wav                            0.007451   0.000571
# 3  0012633b.wav                            0.029096   0.001137
# 4  001ed5f1.wav                            0.002704   0.000891
#
#    Acoustic_guitar  Applause      Bark  Bass_drum  Bass_guitar  \
# 0         0.005911  0.002846  0.003938   0.029490     0.016985
# 1         0.002419  0.002114  0.000322   0.028842     0.116336
# 2         0.012605  0.000485  0.000444   0.128871     0.050547
# 3         0.001985  0.006459  0.002482   0.007694     0.006102
# 4         0.000770  0.003065  0.003242   0.001629     0.001875
#
#    Bathtub_(filling_or_washing)  Bicycle_bell  ...  Toilet_flush  \
# 0                      0.002642      0.039185  ...      0.013232
# 1                      0.000366      0.001327  ...      0.007420
# 2                      0.007274      0.001180  ...      0.006785
# 3                      0.010786      0.001156  ...      0.012058
# 4                      0.018459      0.001690  ...      0.003665
#
#    Traffic_noise_and_roadway_noise  Trickle_and_dribble  Walk_and_footsteps  \
# 0                         0.012250             0.005849            0.006064
# 1                         0.000719             0.000377            0.001667
# 2                         0.000337             0.000824            0.000967
# 3                         0.001664             0.006351            0.011930
# 4                         0.000621             0.005969            0.028185
#
#    Water_tap_and_faucet  Waves_and_surf  Whispering   Writing      Yell  \
# 0              0.010967        0.002437    0.016901  0.010545  0.008778
# 1              0.013575        0.000809    0.001478  0.020437  0.001389
# 2              0.038791        0.000076    0.003901  0.019255  0.000827
# 3              0.016373        0.000901    0.009064  0.024532  0.002560
# 4              0.010478        0.001047    0.025795  0.039417  0.000639
#
#    Zipper_(clothing)
# 0           0.009321
# 1           0.003472
# 2           0.012199
# 3           0.251498
# 4           0.085939
#
# [5 rows x 81 columns]

# %%
sub_df = df_temp.groupby(sample.columns[0]).mean()
sub_df.head()
# Out:
#               Accelerating_and_revving_and_vroom  Accordion  Acoustic_guitar  \
# fname
# 000ccb97.wav                            0.001884   0.003096         0.005911
# 0012633b.wav                            0.024652   0.001353         0.005670
# 001ed5f1.wav                            0.002704   0.000891         0.000770
# 00294be0.wav                            0.004742   0.000748         0.002166
# 003fde7a.wav                            0.000089   0.002555         0.000290
#
#               Applause      Bark  Bass_drum  Bass_guitar  \
# fname
# 000ccb97.wav  0.002846  0.003938   0.029490     0.016985
# 0012633b.wav  0.003019  0.001083   0.055136     0.057662
# 001ed5f1.wav  0.003065  0.003242   0.001629     0.001875
# 00294be0.wav  0.001717  0.005253   0.006480     0.006816
# 003fde7a.wav  0.000333  0.002947   0.000334     0.000224
#
#               Bathtub_(filling_or_washing)  Bicycle_bell  \
# fname
# 000ccb97.wav                      0.002642      0.039185
# 0012633b.wav                      0.006142      0.001221
# 001ed5f1.wav                      0.018459      0.001690
# 00294be0.wav                      0.003031      0.008499
# 003fde7a.wav                      0.000398      0.629203
#
#               Burping_and_eructation  ...  Toilet_flush  \
# fname                                 ...
# 000ccb97.wav                0.010393  ...      0.013232
# 0012633b.wav                0.004893  ...      0.008754
# 001ed5f1.wav                0.006739  ...      0.003665
# 00294be0.wav                0.011594  ...      0.035184
# 003fde7a.wav                0.000801  ...      0.000561
#
#               Traffic_noise_and_roadway_noise  Trickle_and_dribble  \
# fname
# 000ccb97.wav                         0.012250             0.005849
# 0012633b.wav                         0.000906             0.002517
# 001ed5f1.wav                         0.000621             0.005969
# 00294be0.wav                         0.004557             0.009709
# 003fde7a.wav                         0.001677             0.000870
#
#               Walk_and_footsteps  Water_tap_and_faucet  Waves_and_surf  \
# fname
# 000ccb97.wav            0.006064              0.010967        0.002437
# 0012633b.wav            0.004855              0.022913        0.000595
# 001ed5f1.wav            0.028185              0.010478        0.001047
# 00294be0.wav            0.016291              0.022078        0.006311
# 003fde7a.wav            0.001255              0.000446        0.000079
#
#               Whispering   Writing      Yell  Zipper_(clothing)
# fname
# 000ccb97.wav    0.016901  0.010545  0.008778           0.009321
# 0012633b.wav    0.004814  0.021408  0.001592           0.089057
# 001ed5f1.wav    0.025795  0.039417  0.000639           0.085939
# 00294be0.wav    0.014011  0.072279  0.002365           0.020373
# 003fde7a.wav    0.002926  0.003220  0.000525           0.002343
#
# [5 rows x 80 columns]
