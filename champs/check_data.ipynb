# %%
import os
import pandas as pd
import numpy as np

# %%
FOLDER = '../../data_kaggle/champs/'

# %%
os.listdir(FOLDER)
# Out:
# ['mulliken_charges.csv',
#  'sample_submission.csv',
#  'magnetic_shielding_tensors.csv',
#  'train.csv',
#  'test.csv',
#  'dipole_moments.csv',
#  'potential_energy.csv',
#  'structures.csv',
#  'scalar_coupling_contributions.csv',
#  'structures.zip']

# %%
df_train = pd.read_csv(FOLDER + 'train.csv')

# %%
df_train.head()
# Out:
#    id     molecule_name  atom_index_0  atom_index_1  type  \
# 0   0  dsgdb9nsd_000001             1             0  1JHC
# 1   1  dsgdb9nsd_000001             1             2  2JHH
# 2   2  dsgdb9nsd_000001             1             3  2JHH
# 3   3  dsgdb9nsd_000001             1             4  2JHH
# 4   4  dsgdb9nsd_000001             2             0  1JHC
#
#    scalar_coupling_constant
# 0                   84.8076
# 1                  -11.2570
# 2                  -11.2548
# 3                  -11.2543
# 4                   84.8074

# %%
df_test = pd.read_csv(FOLDER + 'test.csv')
df_test[df_test['molecule_name'] == 'dsgdb9nsd_000004']
# Out:
#         id     molecule_name  atom_index_0  atom_index_1  type
# 0  4658147  dsgdb9nsd_000004             2             0  2JHC
# 1  4658148  dsgdb9nsd_000004             2             1  1JHC
# 2  4658149  dsgdb9nsd_000004             2             3  3JHH
# 3  4658150  dsgdb9nsd_000004             3             0  1JHC
# 4  4658151  dsgdb9nsd_000004             3             1  2JHC

# %%
df_train = pd.read_csv(FOLDER + 'train.csv')
df_train[df_train['molecule_name'] == 'dsgdb9nsd_000001']
# Out:
#    id     molecule_name  atom_index_0  atom_index_1  type  \
# 0   0  dsgdb9nsd_000001             1             0  1JHC
# 1   1  dsgdb9nsd_000001             1             2  2JHH
# 2   2  dsgdb9nsd_000001             1             3  2JHH
# 3   3  dsgdb9nsd_000001             1             4  2JHH
# 4   4  dsgdb9nsd_000001             2             0  1JHC
# 5   5  dsgdb9nsd_000001             2             3  2JHH
# 6   6  dsgdb9nsd_000001             2             4  2JHH
# 7   7  dsgdb9nsd_000001             3             0  1JHC
# 8   8  dsgdb9nsd_000001             3             4  2JHH
# 9   9  dsgdb9nsd_000001             4             0  1JHC
#
#    scalar_coupling_constant
# 0                   84.8076
# 1                  -11.2570
# 2                  -11.2548
# 3                  -11.2543
# 4                   84.8074
# 5                  -11.2541
# 6                  -11.2548
# 7                   84.8093
# 8                  -11.2543
# 9                   84.8095

# %%
df_train['type'].value_counts()
# Out:
# 3JHC    1510379
# 2JHC    1140674
# 1JHC     709416
# 3JHH     590611
# 2JHH     378036
# 3JHN     166415
# 2JHN     119253
# 1JHN      43363
# Name: type, dtype: int64

# %%
def idx2elm(atom_label, atom_dict):
    return atom_dict[atom_label]

# %%
i = 0
# array of each column
mols = df_train['molecule_name'].value_counts().index
atom0 = df_train[df_train['molecule_name'] == mols[i]]['atom_index_0'].values
atom1 = df_train[df_train['molecule_name'] == mols[i]]['atom_index_1'].values
types = df_train[df_train['molecule_name'] == mols[i]]['type'].values

# atom index to atom name
atom_idx = df_structures[df_structures['molecule_name'] == mols[i]]['atom_index'].values
atom_name = df_structures[df_structures['molecule_name'] == mols[i]]['atom'].values
atom_dict = {atom_idx[i]:atom_name[i] for i in range(len(atom_idx))}
atom0_elm = df_train[df_train['molecule_name'] == mols[i]]['atom_index_0'].apply(idx2elm, atom_dict=atom_dict)
atom1_elm = df_train[df_train['molecule_name'] == mols[i]]['atom_index_1'].apply(idx2elm, atom_dict=atom_dict)

# %%
df_train[df_train['molecule_name'] == mols[i]]
# Out:
#               id     molecule_name  atom_index_0  atom_index_1  type  \
# 1302988  1302988  dsgdb9nsd_042139             9             0  1JHC
# 1302989  1302989  dsgdb9nsd_042139             9             1  2JHC
# 1302990  1302990  dsgdb9nsd_042139             9             2  3JHC
# 1302991  1302991  dsgdb9nsd_042139             9             7  3JHC
# 1302992  1302992  dsgdb9nsd_042139             9             8  2JHC
# 1302993  1302993  dsgdb9nsd_042139             9            10  2JHH
# 1302994  1302994  dsgdb9nsd_042139             9            11  3JHH
# 1302995  1302995  dsgdb9nsd_042139             9            12  3JHH
# 1302996  1302996  dsgdb9nsd_042139             9            25  3JHH
# 1302997  1302997  dsgdb9nsd_042139             9            26  3JHH
# 1302998  1302998  dsgdb9nsd_042139            10             0  1JHC
# 1302999  1302999  dsgdb9nsd_042139            10             1  2JHC
# 1303000  1303000  dsgdb9nsd_042139            10             2  3JHC
# ...

# %%
# mulliken charge for each atom (train)
# df_mulliken_charges = pd.read_csv(FOLDER + 'mulliken_charges.csv')
df_mulliken_charges[df_mulliken_charges['molecule_name'] == 'dsgdb9nsd_000001']
# Out:
#       molecule_name  atom_index  mulliken_charge
# 0  dsgdb9nsd_000001           0        -0.535689
# 1  dsgdb9nsd_000001           1         0.133921
# 2  dsgdb9nsd_000001           2         0.133922
# 3  dsgdb9nsd_000001           3         0.133923
# 4  dsgdb9nsd_000001           4         0.133923

# %%
# location for each atom (train/test)
df_structures = pd.read_csv(FOLDER + 'structures.csv')
df_structures[df_structures['molecule_name'] == 'dsgdb9nsd_000001']
# Out:
#       molecule_name  atom_index atom         x         y         z
# 0  dsgdb9nsd_000001           0    C -0.012698  1.085804  0.008001
# 1  dsgdb9nsd_000001           1    H  0.002150 -0.006031  0.001976
# 2  dsgdb9nsd_000001           2    H  1.011731  1.463751  0.000277
# 3  dsgdb9nsd_000001           3    H -0.540815  1.447527 -0.876644
# 4  dsgdb9nsd_000001           4    H -0.523814  1.437933  0.906397

# %%
incl_F = df_structures[df_structures['atom'] == 'F']['molecule_name'].values[0]

# %%
df_test[df_test['molecule_name'] == incl_F]
# Out:
# Empty DataFrame
# Columns: [id, molecule_name, atom_index_0, atom_index_1, type]
# Index: []

# %%
# dipole moment for each molecule (train)
df_dipole_moments = pd.read_csv(FOLDER + 'dipole_moments.csv')
df_dipole_moments[df_dipole_moments['molecule_name'] == 'dsgdb9nsd_000001']
# Out:
#       molecule_name    X    Y    Z
# 0  dsgdb9nsd_000001  0.0  0.0  0.0

# %%
# potential energy for each molecule (train)
df_potential_energy = pd.read_csv(FOLDER + 'potential_energy.csv')
df_potential_energy[df_potential_energy['molecule_name'] == 'dsgdb9nsd_000001']
# Out:
#       molecule_name  potential_energy
# 0  dsgdb9nsd_000001         -40.52368

# %%
# scaloar coupling contribution for each pair atoms (train)
df_scalar_coupling_contributions = pd.read_csv(FOLDER + 'scalar_coupling_contributions.csv')
df_scalar_coupling_contributions[df_scalar_coupling_contributions['molecule_name'] == 'dsgdb9nsd_000001']
# Out:
#       molecule_name  atom_index_0  atom_index_1  type       fc        sd  \
# 0  dsgdb9nsd_000001             1             0  1JHC  83.0224  0.254579
# 1  dsgdb9nsd_000001             1             2  2JHH -11.0347  0.352978
# 2  dsgdb9nsd_000001             1             3  2JHH -11.0325  0.352944
# 3  dsgdb9nsd_000001             1             4  2JHH -11.0319  0.352934
# 4  dsgdb9nsd_000001             2             0  1JHC  83.0222  0.254585
# 5  dsgdb9nsd_000001             2             3  2JHH -11.0317  0.352932
# 6  dsgdb9nsd_000001             2             4  2JHH -11.0324  0.352943
# 7  dsgdb9nsd_000001             3             0  1JHC  83.0241  0.254634
# 8  dsgdb9nsd_000001             3             4  2JHH -11.0319  0.352943
# 9  dsgdb9nsd_000001             4             0  1JHC  83.0243  0.254628
#
#        pso       dso
# 0  1.25862  0.272010
# 1  2.85839 -3.433600
# 2  2.85852 -3.433870
# 3  2.85855 -3.433930
# 4  1.25861  0.272013
# 5  2.85856 -3.433950
# ...

# %%
# magnetic schielding tensor for each atom (train)
df_magnetic_shielding_tensors = pd.read_csv(FOLDER + 'magnetic_shielding_tensors.csv')
df_magnetic_shielding_tensors[df_magnetic_shielding_tensors['molecule_name'] == 'dsgdb9nsd_000001']
# Out:
#       molecule_name  atom_index        XX      YX      ZX      XY        YY  \
# 0  dsgdb9nsd_000001           0  195.3150  0.0000 -0.0001  0.0000  195.3170
# 1  dsgdb9nsd_000001           1   31.3410 -1.2317  4.0544 -1.2317   28.9546
# 2  dsgdb9nsd_000001           2   31.5814  1.2173 -4.1474  1.2173   28.9036
# 3  dsgdb9nsd_000001           3   31.5172  4.1086  1.2723  4.1088   33.9068
# 4  dsgdb9nsd_000001           4   31.4029 -4.0942 -1.1793 -4.0944   34.0776
#
#        ZY      XZ      YZ        ZZ
# 0  0.0007 -0.0001  0.0007  195.3170
# 1 -1.7173  4.0546 -1.7173   34.0861
# 2 -1.6036 -4.1476 -1.6036   33.8967
# 3  1.6950  1.2724  1.6951   28.9579
# 4  1.6259 -1.1795  1.6260   28.9013

# %%
atoms = df_structures['atom'].value_counts().index

# %%
num_atoms = len(atoms)
pair_list = []
for i in range(num_atoms):
    for j in range(i):
        pair_list.append([atoms[i], atoms[j]])

# %%
pair_list
# Out:
# [['C', 'H'],
#  ['O', 'H'],
#  ['O', 'C'],
#  ['N', 'H'],
#  ['N', 'C'],
#  ['N', 'O'],
#  ['F', 'H'],
#  ['F', 'C'],
#  ['F', 'O'],
#  ['F', 'N']]
